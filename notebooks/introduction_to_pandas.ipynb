# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sassoftware/sas-viya-programming/master/data/cars.csv')

# %%
df
# Out:
#            Make                             Model    Type  Origin DriveTrain  \
# 0         Acura                               MDX     SUV    Asia        All
# 1         Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2         Acura                           TSX 4dr   Sedan    Asia      Front
# 3         Acura                            TL 4dr   Sedan    Asia      Front
# 4         Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5         Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6         Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7          Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8          Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9          Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10         Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            Make                             Model    Type  Origin DriveTrain  \
# 0         Acura                               MDX     SUV    Asia        All
# 1         Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2         Acura                           TSX 4dr   Sedan    Asia      Front
# 3         Acura                            TL 4dr   Sedan    Asia      Front
# 4         Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5         Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6         Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7          Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8          Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9          Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10         Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# ...

# %%
subdf = df[['Make', 'Model', 'Horsepower']]

# %%
subdf.head
# Out:
# <bound method NDFrame.head of            Make                             Model  Horsepower
# 0         Acura                               MDX       265.0
# 1         Acura                    RSX Type S 2dr       200.0
# 2         Acura                           TSX 4dr       200.0
# 3         Acura                            TL 4dr       270.0
# 4         Acura                        3.5 RL 4dr       225.0
# 5         Acura           3.5 RL w/Navigation 4dr       225.0
# 6         Acura            NSX coupe 2dr manual S       290.0
# 7          Audi                       A4 1.8T 4dr       170.0
# 8          Audi            A41.8T convertible 2dr       170.0
# 9          Audi                        A4 3.0 4dr       220.0
# 10         Audi         A4 3.0 Quattro 4dr manual       220.0
# 11         Audi           A4 3.0 Quattro 4dr auto       220.0
# 12         Audi                        A6 3.0 4dr       220.0
# 13         Audi                A6 3.0 Quattro 4dr       220.0
# ...

# %%
model = df.Model # df['Model']
model.head
# Out:
# <bound method NDFrame.head of 0                                   MDX
# 1                        RSX Type S 2dr
# 2                               TSX 4dr
# 3                                TL 4dr
# 4                            3.5 RL 4dr
# 5               3.5 RL w/Navigation 4dr
# 6                NSX coupe 2dr manual S
# 7                           A4 1.8T 4dr
# 8                A41.8T convertible 2dr
# 9                            A4 3.0 4dr
# 10            A4 3.0 Quattro 4dr manual
# 11              A4 3.0 Quattro 4dr auto
# 12                           A6 3.0 4dr
# 13                   A6 3.0 Quattro 4dr
# 14               A4 3.0 convertible 2dr
# 15       A4 3.0 Quattro convertible 2dr
# 16             A6 2.7 Turbo Quattro 4dr
# 17                   A6 4.2 Quattro 4dr
# 18                     A8 L Quattro 4dr
# 19                       S4 Quattro 4dr
# 20                             RS 6 4dr
# 21       TT 1.8 convertible 2dr (coupe)
# 22     TT 1.8 Quattro 2dr (convertible)
# ...

# %%
df.iloc[2:7]
# Out:
#     Make                    Model    Type Origin DriveTrain     MSRP  Invoice  \
# 2  Acura                  TSX 4dr   Sedan   Asia      Front  26990.0  24647.0
# 3  Acura                   TL 4dr   Sedan   Asia      Front  33195.0  30299.0
# 4  Acura               3.5 RL 4dr   Sedan   Asia      Front  43755.0  39014.0
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan   Asia      Front  46100.0  41100.0
# 6  Acura   NSX coupe 2dr manual S  Sports   Asia       Rear  89765.0  79978.0
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
# 5         3.5        6.0       225.0      18.0         24.0  3893.0
# 6         3.2        6.0       290.0      17.0         24.0  3153.0
#
#    Wheelbase  Length
# 2      105.0   183.0
# 3      108.0   186.0
# ...
